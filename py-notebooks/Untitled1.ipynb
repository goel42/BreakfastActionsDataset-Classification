# %%
#transforting .gz to .npy
import os
import numpy as np

# %%
visual_feat_path = r"C:\Users\dcsang\PycharmProjects\embedding\breakfast\Breakfast_fs\data"
text_path = r"C:\Users\dcsang\PycharmProjects\embedding\breakfast\Breakfast_fs\groundTruth"
map_path = r"C:\Users\dcsang\PycharmProjects\embedding\breakfast\Breakfast_fs\splits\mapping.txt"


visual_feat_path_train = os.path.join(visual_feat_path, "train")
text_path_train = os.path.join(text_path, "train")

visual_feat_path_test = os.path.join(visual_feat_path, "test")
text_path_test = os.path.join(text_path, "test")


new_vis_path_train = r"C:\Users\dcsang\PycharmProjects\embedding\breakfast\Breakfast_fs\data_npy\train"
new_vis_path_test = r"C:\Users\dcsang\PycharmProjects\embedding\breakfast\Breakfast_fs\data_npy\test"

# %%
for vf in os.listdir(visual_feat_path_train):
    temp = vf[:-3]
    feats = np.loadtxt(os.path.join(visual_feat_path_train, vf), dtype = 'float32')
    print(feats.shape)
    np.save(os.path.join(new_vis_path_train, temp), feats)
# Out:
# (544, 400)
# (6932, 400)
# (2238, 400)
# (884, 400)
# (8040, 400)
# (4136, 400)
# (1937, 400)
# (362, 400)
# (545, 400)
# (571, 400)
# (6932, 400)
# (2238, 400)
# (884, 400)
# (8040, 400)
# (4136, 400)
# (1937, 400)
# (5191, 400)
# (362, 400)
# (544, 400)
# (6932, 400)
# (2238, 400)
# (884, 400)
# (8040, 400)
# (4136, 400)
# (1937, 400)
# (5191, 400)
# (362, 400)
# (544, 400)
# (570, 400)
# (6932, 400)
# (2238, 400)
# (884, 400)
# (8040, 400)
# (4136, 400)
# (1937, 400)
# (5191, 400)
# (362, 400)
# (621, 400)
# (359, 400)
# (2900, 400)
# (1354, 400)
# (1201, 400)
# (5999, 400)
# (3789, 400)
# (755, 400)
# (700, 400)
# (619, 400)
# (359, 400)
# (2900, 400)
# (1353, 400)
# (1201, 400)
# (5999, 400)
# (3789, 400)
# (700, 400)
# (620, 400)
# (359, 400)
# (2900, 400)
# (1353, 400)
# (1201, 400)
# (3789, 400)
# (7910, 400)
# (698, 400)
# (620, 400)
# (359, 400)
# (2900, 400)
# (1353, 400)
# (1201, 400)
# (5999, 400)
# (3789, 400)
# (7910, 400)
# (703, 400)
# (461, 400)
# (344, 400)
# ...

# %%
for vf in os.listdir(visual_feat_path_test):
    temp = vf[:-3]
    feats = np.loadtxt(os.path.join(visual_feat_path_test, vf), dtype = 'float32')
    print(feats.shape)
    np.save(os.path.join(new_vis_path_test, temp), feats)
# Out:
# (832, 400)
# (917, 400)
# (4266, 400)
# (1158, 400)
# (4449, 400)
# (3040, 400)
# (1310, 400)
# (832, 400)
# (917, 400)
# (1157, 400)
# (3040, 400)
# (1310, 400)
# (832, 400)
# (917, 400)
# (4266, 400)
# (1157, 400)
# (4449, 400)
# (3041, 400)
# (1310, 400)
# (833, 400)
# (917, 400)
# (4266, 400)
# (1157, 400)
# (4449, 400)
# (3040, 400)
# (1310, 400)
# (481, 400)
# (3357, 400)
# (745, 400)
# (6692, 400)
# (1445, 400)
# (2718, 400)
# (396, 400)
# (481, 400)
# (3357, 400)
# (753, 400)
# (6692, 400)
# (1446, 400)
# (2720, 400)
# (396, 400)
# (479, 400)
# (3352, 400)
# (747, 400)
# (6692, 400)
# (2777, 400)
# (1445, 400)
# (2725, 400)
# (395, 400)
# (481, 400)
# (3357, 400)
# (734, 400)
# (6692, 400)
# (2777, 400)
# (1445, 400)
# (2725, 400)
# (396, 400)
# (1182, 400)
# (1119, 400)
# (3407, 400)
# (2791, 400)
# (5892, 400)
# (3843, 400)
# (2740, 400)
# (2696, 400)
# (1661, 400)
# (2791, 400)
# (1080, 400)
# (497, 400)
# (472, 400)
# (2205, 400)
# (1314, 400)
# (583, 400)
# (4984, 400)
# ...
